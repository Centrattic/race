# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ## Training Model

# %% [markdown]
# #### Very useful to mark succesful training
#
# https://machinelearningmastery.com/practical-guide-to-gan-failure-modes/

# %%
os.getcwd()
# Out:
# '/users/riya/race/gancode'

# %%
os.chdir('/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/')
os.getcwd()
# Out:
# '/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix'

# %%
os.listdir('/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/checkpoints/edges2shoes/web/images')
# Out:
# ['epoch070_real_B.png',
#  'epoch003_real_B.png',
#  'epoch058_fake_B.png',
#  'epoch080_real_B.png',
#  'epoch138_real_A.png',
#  'epoch066_real_B.png',
#  'epoch015_real_B.png',
#  'epoch096_real_B.png',
#  'epoch181_real_A.png',
#  'epoch084_fake_B.png',
#  'epoch102_real_A.png',
#  'epoch007_fake_B.png',
#  'epoch074_fake_B.png',
#  'epoch171_real_A.png',
#  'epoch197_real_A.png',
#  'epoch092_fake_B.png',
#  'epoch114_real_A.png',
#  'epoch011_fake_B.png',
#  'epoch062_fake_B.png',
#  'epoch167_real_A.png',
#  'epoch039_real_B.png',
#  'epoch071_real_A.png',
#  'epoch174_fake_B.png',
#  'epoch107_fake_B.png',
#  'epoch002_real_A.png',
#  'epoch184_fake_B.png',
#  'epoch081_real_A.png',
#  'epoch139_real_B.png',
#  'epoch067_real_A.png',
#  'epoch162_fake_B.png',
#  'epoch111_fake_B.png',
#  'epoch014_real_A.png',
#  'epoch192_fake_B.png',
#  'epoch097_real_A.png',
#  'epoch180_real_B.png',
#  'epoch158_fake_B.png',
#  'epoch103_real_B.png',
#  'epoch170_real_B.png',
#  'epoch196_real_B.png',
#  'epoch115_real_B.png',
#  'epoch166_real_B.png',
#  'epoch038_real_A.png',
#  'epoch145_fake_B.png',
#  'epoch040_real_A.png',
#  'epoch033_real_A.png',
#  'epoch136_fake_B.png',
#  'epoch108_real_B.png',
#  'epoch153_fake_B.png',
#  'epoch056_real_A.png',
#  'epoch025_real_A.png',
#  'epoch120_fake_B.png',
#  'epoch169_fake_B.png',
#  'epoch132_real_B.png',
#  'epoch141_real_B.png',
#  'epoch199_fake_B.png',
#  'epoch124_real_B.png',
#  'epoch157_real_B.png',
#  'epoch009_real_A.png',
#  'epoch099_fake_B.png',
#  'epoch041_real_B.png',
#  'epoch032_real_B.png',
#  'epoch069_fake_B.png',
#  'epoch109_real_A.png',
#  'epoch057_real_B.png',
#  'epoch024_real_B.png',
#  'epoch036_fake_B.png',
#  'epoch133_real_A.png',
#  'epoch140_real_A.png',
#  'epoch045_fake_B.png',
#  'epoch020_fake_B.png',
#  'epoch125_real_A.png',
#  'epoch156_real_A.png',
#  'epoch053_fake_B.png',
#  'epoch008_real_B.png',
#  'epoch127_fake_B.png',
#  'epoch022_real_A.png',
#  'epoch051_real_A.png',
#  'epoch154_fake_B.png',
#  'epoch131_fake_B.png',
#  'epoch034_real_A.png',
#  'epoch047_real_A.png',
#  'epoch142_fake_B.png',
#  'epoch119_real_B.png',
#  'epoch150_real_B.png',
#  'epoch188_fake_B.png',
#  'epoch123_real_B.png',
#  'epoch178_fake_B.png',
#  'epoch018_real_A.png',
#  'epoch146_real_B.png',
#  'epoch135_real_B.png',
#  'epoch078_fake_B.png',
#  'epoch023_real_B.png',
#  'epoch088_fake_B.png',
#  'epoch050_real_B.png',
#  'epoch035_real_B.png',
#  'epoch046_real_B.png',
#  'epoch118_real_A.png',
#  'epoch200_fake_B.png',
#  'epoch054_fake_B.png',
#  'epoch151_real_A.png',
#  'epoch122_real_A.png',
#  'epoch027_fake_B.png',
#  'epoch019_real_B.png',
#  'epoch042_fake_B.png',
#  'epoch147_real_A.png',
#  'epoch134_real_A.png',
#  'epoch031_fake_B.png',
#  'epoch049_fake_B.png',
#  'epoch091_real_B.png',
#  'epoch012_real_B.png',
#  'epoch061_real_B.png',
#  'epoch087_real_B.png',
#  'epoch004_real_B.png',
#  'epoch077_real_B.png',
#  'epoch129_real_A.png',
#  'epoch160_real_A.png',
#  'epoch065_fake_B.png',
#  'epoch016_fake_B.png',
#  'epoch113_real_A.png',
#  'epoch095_fake_B.png',
#  'epoch190_real_A.png',
#  'epoch028_real_B.png',
#  'epoch176_real_A.png',
#  'epoch073_fake_B.png',
#  'epoch105_real_A.png',
#  'epoch083_fake_B.png',
#  'epoch186_real_A.png',
#  'epoch090_real_A.png',
#  'epoch195_fake_B.png',
#  'epoch013_real_A.png',
#  'epoch116_fake_B.png',
#  'epoch165_fake_B.png',
#  'epoch060_real_A.png',
#  'epoch086_real_A.png',
#  'epoch183_fake_B.png',
#  'epoch005_real_A.png',
#  'epoch100_fake_B.png',
#  'epoch173_fake_B.png',
#  'epoch076_real_A.png',
#  'epoch128_real_B.png',
#  'epoch161_real_B.png',
#  'epoch112_real_B.png',
#  'epoch191_real_B.png',
#  'epoch149_fake_B.png',
#  'epoch029_real_A.png',
#  'epoch177_real_B.png',
#  'epoch104_real_B.png',
#  'epoch187_real_B.png',
#  'epoch160_fake_B.png',
#  'epoch065_real_A.png',
#  'epoch148_real_B.png',
#  'epoch095_real_A.png',
#  'epoch190_fake_B.png',
#  'epoch016_real_A.png',
#  'epoch113_fake_B.png',
#  'epoch176_fake_B.png',
#  'epoch073_real_A.png',
#  'epoch083_real_A.png',
#  'epoch186_fake_B.png',
#  'epoch105_fake_B.png',
#  'epoch117_real_B.png',
#  'epoch049_real_A.png',
#  'epoch194_real_B.png',
#  'epoch164_real_B.png',
#  'epoch101_real_B.png',
#  'epoch182_real_B.png',
#  'epoch129_fake_B.png',
#  'epoch172_real_B.png',
#  'epoch064_real_B.png',
#  'epoch094_real_B.png',
#  'epoch149_real_A.png',
#  'epoch017_real_B.png',
#  'epoch072_real_B.png',
#  'epoch029_fake_B.png',
#  'epoch082_real_B.png',
#  'epoch001_real_B.png',
#  'epoch013_fake_B.png',
#  'epoch116_real_A.png',
#  'epoch090_fake_B.png',
#  'epoch195_real_A.png',
#  'epoch048_real_B.png',
#  'epoch165_real_A.png',
#  'epoch060_fake_B.png',
#  'epoch005_fake_B.png',
#  'epoch100_real_A.png',
#  'epoch086_fake_B.png',
#  'epoch183_real_A.png',
#  'epoch173_real_A.png',
#  'epoch076_fake_B.png',
#  'epoch055_real_B.png',
#  'epoch188_real_A.png',
#  'epoch178_real_A.png',
#  'epoch026_real_B.png',
#  'epoch043_real_B.png',
#  'epoch018_fake_B.png',
#  'epoch030_real_B.png',
#  'epoch127_real_A.png',
#  'epoch022_fake_B.png',
#  'epoch079_real_B.png',
#  'epoch051_fake_B.png',
#  'epoch154_real_A.png',
#  'epoch089_real_B.png',
#  'epoch131_real_A.png',
#  'epoch034_fake_B.png',
#  'epoch047_fake_B.png',
#  'epoch142_real_A.png',
#  'epoch189_real_B.png',
#  'epoch200_real_A.png',
#  'epoch054_real_A.png',
#  'epoch151_fake_B.png',
#  'epoch179_real_B.png',
#  'epoch122_fake_B.png',
#  'epoch027_real_A.png',
#  'epoch042_real_A.png',
#  'epoch147_fake_B.png',
#  'epoch134_fake_B.png',
#  'epoch031_real_A.png',
#  'epoch126_real_B.png',
#  'epoch078_real_A.png',
#  'epoch088_real_A.png',
#  'epoch155_real_B.png',
#  'epoch130_real_B.png',
#  'epoch118_fake_B.png',
#  'epoch143_real_B.png',
#  'epoch037_real_B.png',
#  'epoch169_real_A.png',
#  'epoch044_real_B.png',
#  'epoch199_real_A.png',
#  'epoch021_real_B.png',
#  'epoch009_fake_B.png',
#  'epoch052_real_B.png',
#  'epoch145_real_A.png',
#  'epoch040_fake_B.png',
#  'epoch098_real_B.png',
#  'epoch068_real_B.png',
#  'epoch033_fake_B.png',
#  'epoch136_real_A.png',
#  'epoch153_real_A.png',
#  'epoch056_fake_B.png',
#  'epoch025_fake_B.png',
#  'epoch120_real_A.png',
#  'epoch036_real_A.png',
#  'epoch133_fake_B.png',
#  'epoch168_real_B.png',
#  'epoch198_real_B.png',
#  'epoch140_fake_B.png',
#  'epoch045_real_A.png',
#  'epoch020_real_A.png',
#  'epoch125_fake_B.png',
#  'epoch156_fake_B.png',
#  'epoch053_real_A.png',
#  'epoch099_real_A.png',
#  'epoch144_real_B.png',
#  'epoch069_real_A.png',
#  'epoch137_real_B.png',
#  'epoch152_real_B.png',
#  'epoch109_fake_B.png',
#  'epoch121_real_B.png',
#  'epoch102_fake_B.png',
#  'epoch007_real_A.png',
#  'epoch159_real_B.png',
#  'epoch181_fake_B.png',
#  'epoch084_real_A.png',
#  'epoch074_real_A.png',
#  'epoch171_fake_B.png',
#  'epoch114_fake_B.png',
#  'epoch011_real_A.png',
#  'epoch197_fake_B.png',
#  'epoch092_real_A.png',
#  'epoch062_real_A.png',
#  'epoch167_fake_B.png',
#  'epoch175_real_B.png',
#  'epoch058_real_A.png',
#  'epoch185_real_B.png',
#  'epoch106_real_B.png',
#  'epoch163_real_B.png',
#  'epoch138_fake_B.png',
#  'epoch193_real_B.png',
#  'epoch110_real_B.png',
#  'epoch006_real_B.png',
#  'epoch085_real_B.png',
#  'epoch158_real_A.png',
#  'epoch075_real_B.png',
#  'epoch010_real_B.png',
#  'epoch093_real_B.png',
#  'epoch038_fake_B.png',
#  'epoch063_real_B.png',
#  'epoch071_fake_B.png',
#  'epoch174_real_A.png',
#  'epoch184_real_A.png',
#  'epoch081_fake_B.png',
#  'epoch059_real_B.png',
#  'epoch107_real_A.png',
#  'epoch002_fake_B.png',
#  'epoch067_fake_B.png',
#  'epoch162_real_A.png',
#  'epoch192_real_A.png',
#  'epoch097_fake_B.png',
#  'epoch111_real_A.png',
#  'epoch014_fake_B.png',
#  'epoch098_real_A.png',
#  'epoch145_real_B.png',
#  'epoch068_real_A.png',
#  'epoch136_real_B.png',
#  'epoch153_real_B.png',
#  'epoch108_fake_B.png',
#  'epoch120_real_B.png',
#  'epoch132_fake_B.png',
#  'epoch037_real_A.png',
#  'epoch169_real_B.png',
#  'epoch199_real_B.png',
#  'epoch044_real_A.png',
#  'epoch141_fake_B.png',
#  'epoch124_fake_B.png',
#  'epoch021_real_A.png',
#  'epoch052_real_A.png',
#  'epoch157_fake_B.png',
#  'epoch041_fake_B.png',
#  'epoch144_real_A.png',
#  'epoch099_real_B.png',
#  'epoch069_real_B.png',
#  'epoch137_real_A.png',
#  'epoch032_fake_B.png',
#  'epoch057_fake_B.png',
#  'epoch152_real_A.png',
#  'epoch121_real_A.png',
#  'epoch024_fake_B.png',
#  'epoch036_real_B.png',
#  'epoch168_real_A.png',
#  'epoch045_real_B.png',
#  'epoch198_real_A.png',
#  'epoch020_real_B.png',
#  'epoch008_fake_B.png',
#  'epoch053_real_B.png',
#  'epoch175_real_A.png',
#  'epoch070_fake_B.png',
#  'epoch080_fake_B.png',
#  'epoch185_real_A.png',
#  'epoch058_real_B.png',
#  'epoch003_fake_B.png',
#  'epoch106_real_A.png',
#  'epoch163_real_A.png',
#  'epoch066_fake_B.png',
#  'epoch096_fake_B.png',
#  'epoch193_real_A.png',
#  'epoch015_fake_B.png',
#  'epoch110_real_A.png',
#  'epoch007_real_B.png',
#  'epoch084_real_B.png',
#  'epoch159_real_A.png',
#  'epoch074_real_B.png',
#  'epoch011_real_B.png',
#  'epoch092_real_B.png',
#  'epoch039_fake_B.png',
#  'epoch062_real_B.png',
#  'epoch174_real_B.png',
#  'epoch059_real_A.png',
#  'epoch184_real_B.png',
#  'epoch107_real_B.png',
#  'epoch162_real_B.png',
#  'epoch139_fake_B.png',
#  'epoch192_real_B.png',
#  'epoch111_real_B.png',
#  'epoch006_real_A.png',
#  'epoch103_fake_B.png',
#  'epoch158_real_B.png',
#  'epoch085_real_A.png',
#  'epoch180_fake_B.png',
#  'epoch170_fake_B.png',
#  'epoch075_real_A.png',
#  'epoch010_real_A.png',
#  'epoch115_fake_B.png',
#  'epoch093_real_A.png',
#  'epoch196_fake_B.png',
#  'epoch166_fake_B.png',
#  'epoch063_real_A.png',
#  'epoch117_real_A.png',
#  'epoch012_fake_B.png',
#  'epoch194_real_A.png',
#  'epoch091_fake_B.png',
#  'epoch049_real_B.png',
#  'epoch061_fake_B.png',
#  'epoch164_real_A.png',
#  'epoch101_real_A.png',
#  'epoch004_fake_B.png',
#  'epoch182_real_A.png',
#  'epoch087_fake_B.png',
#  'epoch077_fake_B.png',
#  'epoch172_real_A.png',
#  'epoch065_real_B.png',
#  'epoch095_real_B.png',
#  'epoch148_real_A.png',
#  'epoch016_real_B.png',
#  'epoch073_real_B.png',
#  'epoch028_fake_B.png',
#  'epoch083_real_B.png',
#  'epoch116_real_B.png',
#  'epoch048_real_A.png',
#  'epoch195_real_B.png',
#  'epoch165_real_B.png',
#  'epoch100_real_B.png',
#  'epoch183_real_B.png',
#  'epoch128_fake_B.png',
#  'epoch173_real_B.png',
#  'epoch064_real_A.png',
#  'epoch161_fake_B.png',
#  'epoch149_real_B.png',
#  'epoch191_fake_B.png',
#  'epoch094_real_A.png',
#  'epoch112_fake_B.png',
#  'epoch017_real_A.png',
#  'epoch072_real_A.png',
#  'epoch177_fake_B.png',
#  'epoch187_fake_B.png',
#  'epoch082_real_A.png',
#  'epoch104_fake_B.png',
#  'epoch001_real_A.png',
#  'epoch127_real_B.png',
#  'epoch079_real_A.png',
#  'epoch089_real_A.png',
#  'epoch154_real_B.png',
#  'epoch131_real_B.png',
#  'epoch119_fake_B.png',
#  'epoch142_real_B.png',
#  'epoch188_real_B.png',
#  'epoch150_fake_B.png',
#  'epoch055_real_A.png',
#  'epoch178_real_B.png',
#  'epoch026_real_A.png',
#  'epoch123_fake_B.png',
#  'epoch146_fake_B.png',
#  'epoch043_real_A.png',
#  'epoch030_real_A.png',
#  'epoch135_fake_B.png',
#  'epoch023_fake_B.png',
#  'epoch126_real_A.png',
#  'epoch078_real_B.png',
#  'epoch155_real_A.png',
#  'epoch050_fake_B.png',
#  'epoch088_real_B.png',
#  'epoch035_fake_B.png',
#  'epoch130_real_A.png',
#  'epoch143_real_A.png',
#  'epoch046_fake_B.png',
#  'epoch054_real_B.png',
#  'epoch200_real_B.png',
#  'epoch189_real_A.png',
#  'epoch179_real_A.png',
#  'epoch027_real_B.png',
#  'epoch042_real_B.png',
#  'epoch019_fake_B.png',
#  'epoch031_real_B.png',
#  'epoch150_real_A.png',
#  'epoch055_fake_B.png',
#  'epoch026_fake_B.png',
#  'epoch123_real_A.png',
#  'epoch018_real_B.png',
#  'epoch146_real_A.png',
#  'epoch043_fake_B.png',
#  'epoch030_fake_B.png',
#  'epoch135_real_A.png',
#  'epoch079_fake_B.png',
#  'epoch022_real_B.png',
#  'epoch089_fake_B.png',
#  'epoch051_real_B.png',
#  'epoch034_real_B.png',
#  'epoch047_real_B.png',
#  'epoch119_real_A.png',
#  'epoch151_real_B.png',
#  'epoch189_fake_B.png',
#  'epoch122_real_B.png',
#  'epoch179_fake_B.png',
#  'epoch019_real_A.png',
#  'epoch147_real_B.png',
#  'epoch134_real_B.png',
#  'epoch023_real_A.png',
#  'epoch126_fake_B.png',
#  'epoch155_fake_B.png',
#  'epoch050_real_A.png',
#  'epoch035_real_A.png',
#  'epoch130_fake_B.png',
#  'epoch143_fake_B.png',
#  'epoch046_real_A.png',
#  'epoch118_real_B.png',
#  'epoch160_real_B.png',
#  'epoch113_real_B.png',
#  'epoch190_real_B.png',
#  'epoch148_fake_B.png',
#  'epoch028_real_A.png',
#  'epoch176_real_B.png',
#  'epoch105_real_B.png',
#  'epoch186_real_B.png',
#  'epoch194_fake_B.png',
#  'epoch091_real_A.png',
#  'epoch117_fake_B.png',
#  'epoch012_real_A.png',
#  'epoch061_real_A.png',
#  'epoch164_fake_B.png',
#  'epoch182_fake_B.png',
#  'epoch087_real_A.png',
#  'epoch101_fake_B.png',
#  'epoch004_real_A.png',
#  'epoch077_real_A.png',
#  'epoch172_fake_B.png',
#  'epoch129_real_B.png',
#  'epoch064_fake_B.png',
#  'epoch161_real_A.png',
#  'epoch112_real_A.png',
#  'epoch017_fake_B.png',
#  'epoch191_real_A.png',
#  'epoch094_fake_B.png',
#  'epoch029_real_B.png',
#  'epoch072_fake_B.png',
#  'epoch177_real_A.png',
#  'epoch104_real_A.png',
#  'epoch001_fake_B.png',
#  'epoch187_real_A.png',
#  'epoch082_fake_B.png',
#  'epoch048_fake_B.png',
#  'epoch090_real_B.png',
#  'epoch013_real_B.png',
#  'epoch060_real_B.png',
#  'epoch086_real_B.png',
#  'epoch005_real_B.png',
#  'epoch076_real_B.png',
#  'epoch128_real_A.png',
#  'epoch181_real_B.png',
#  'epoch159_fake_B.png',
#  'epoch102_real_B.png',
#  'epoch171_real_B.png',
#  'epoch197_real_B.png',
#  'epoch114_real_B.png',
#  'epoch167_real_B.png',
#  'epoch039_real_A.png',
#  'epoch175_fake_B.png',
#  'epoch070_real_A.png',
#  'epoch003_real_A.png',
#  'epoch106_fake_B.png',
#  'epoch080_real_A.png',
#  'epoch185_fake_B.png',
#  'epoch138_real_B.png',
#  'epoch163_fake_B.png',
#  'epoch066_real_A.png',
#  'epoch015_real_A.png',
#  'epoch110_fake_B.png',
#  'epoch096_real_A.png',
#  'epoch193_fake_B.png',
#  'epoch085_fake_B.png',
#  'epoch180_real_A.png',
#  'epoch006_fake_B.png',
#  'epoch103_real_A.png',
#  'epoch170_real_A.png',
#  'epoch075_fake_B.png',
#  'epoch093_fake_B.png',
#  'epoch196_real_A.png',
#  'epoch010_fake_B.png',
#  'epoch115_real_A.png',
#  'epoch166_real_A.png',
#  'epoch063_fake_B.png',
#  'epoch038_real_B.png',
#  'epoch071_real_B.png',
#  'epoch002_real_B.png',
#  'epoch059_fake_B.png',
#  'epoch081_real_B.png',
#  'epoch139_real_A.png',
#  'epoch067_real_B.png',
#  'epoch014_real_B.png',
#  'epoch097_real_B.png',
#  'epoch132_real_A.png',
#  'epoch037_fake_B.png',
#  'epoch044_fake_B.png',
#  'epoch141_real_A.png',
#  'epoch124_real_A.png',
#  'epoch021_fake_B.png',
#  'epoch052_fake_B.png',
#  'epoch157_real_A.png',
#  'epoch009_real_B.png',
#  'epoch098_fake_B.png',
#  'epoch040_real_B.png',
#  'epoch033_real_B.png',
#  'epoch068_fake_B.png',
#  'epoch108_real_A.png',
#  'epoch056_real_B.png',
#  'epoch025_real_B.png',
#  'epoch168_fake_B.png',
#  'epoch133_real_B.png',
#  'epoch140_real_B.png',
#  'epoch198_fake_B.png',
#  'epoch125_real_B.png',
#  'epoch156_real_B.png',
#  'epoch008_real_A.png',
#  'epoch041_real_A.png',
#  'epoch144_fake_B.png',
#  'epoch137_fake_B.png',
#  'epoch032_real_A.png',
#  'epoch109_real_B.png',
#  'epoch057_real_A.png',
#  'epoch152_fake_B.png',
#  'epoch121_fake_B.png',
#  'epoch024_real_A.png']

# %%
# !ls checkpoints/edges2shoes
# Out:
# 100_net_D.pth  140_net_D.pth  180_net_D.pth  40_net_D.pth  80_net_D.pth
# 100_net_G.pth  140_net_G.pth  180_net_G.pth  40_net_G.pth  80_net_G.pth
# 105_net_D.pth  145_net_D.pth  185_net_D.pth  45_net_D.pth  85_net_D.pth
# 105_net_G.pth  145_net_G.pth  185_net_G.pth  45_net_G.pth  85_net_G.pth
# 10_net_D.pth   150_net_D.pth  190_net_D.pth  50_net_D.pth  90_net_D.pth
# 10_net_G.pth   150_net_G.pth  190_net_G.pth  50_net_G.pth  90_net_G.pth
# 110_net_D.pth  155_net_D.pth  195_net_D.pth  55_net_D.pth  95_net_D.pth
# 110_net_G.pth  155_net_G.pth  195_net_G.pth  55_net_G.pth  95_net_G.pth
# 115_net_D.pth  15_net_D.pth   200_net_D.pth  5_net_D.pth   latest_net_D.pth
# 115_net_G.pth  15_net_G.pth   200_net_G.pth  5_net_G.pth   latest_net_G.pth
# 120_net_D.pth  160_net_D.pth  20_net_D.pth   60_net_D.pth  loss_log.txt
# 120_net_G.pth  160_net_G.pth  20_net_G.pth   60_net_G.pth  test_opt.txt
# 125_net_D.pth  165_net_D.pth  25_net_D.pth   65_net_D.pth  train_opt.txt
# 125_net_G.pth  165_net_G.pth  25_net_G.pth   65_net_G.pth  web
# 130_net_D.pth  170_net_D.pth  30_net_D.pth   70_net_D.pth
# 130_net_G.pth  170_net_G.pth  30_net_G.pth   70_net_G.pth
# 135_net_D.pth  175_net_D.pth  35_net_D.pth   75_net_D.pth
# 135_net_G.pth  175_net_G.pth  35_net_G.pth   75_net_G.pth

# %%
# !python train.py --dataroot /users/riya/race/gandataset --lr 0.000001 --display_port 8101 --name raceGAN_test4 --model pix2pix --gpu_ids 3 --load_size 256 --crop_size 256
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /users/riya/race/gandataset   	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8101                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 3                             	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 100.0
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256                           	[default: 286]
#                        lr: 1e-06                         	[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: raceGAN_test4                 	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                   no_html: False
#                      norm: batch
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 0
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                 use_wandb: False
#                   verbose: False
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# The number of training images = 1623
# initialize network with normal
# initialize network with normal
# model [Pix2PixModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.414 M
# [Network D] Total number of parameters : 2.769 M
# -----------------------------------------------
# Setting up a new session...
# Exception in user code:
# ------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connection.py", line 175, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py", line 710, in urlopen
#     chunked=chunked,
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py", line 398, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connection.py", line 239, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/usr/lib/python3.6/http/client.py", line 1281, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/usr/lib/python3.6/http/client.py", line 1327, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/usr/lib/python3.6/http/client.py", line 1276, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/usr/lib/python3.6/http/client.py", line 1042, in _send_output
#     self.send(msg)
#   File "/usr/lib/python3.6/http/client.py", line 980, in send
#     self.connect()
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connection.py", line 187, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fd0dec45550>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py", line 786, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8101): Max retries exceeded with url: /env/main (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd0dec45550>: Failed to establish a new connection: [Errno 111] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/visdom/__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "/usr/local/lib/python3.6/dist-packages/visdom/__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "/usr/local/lib/python3.6/dist-packages/requests/sessions.py", line 590, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8101): Max retries exceeded with url: /env/main (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd0dec45550>: Failed to establish a new connection: [Errno 111] Connection refused',))
# [Errno 111] Connection refused
#
#
# Could not connect to Visdom server.
#  Trying to start a server....
# Command: /usr/local/bin/python -m visdom.server -p 8101 &>/dev/null &
# create web directory ./checkpoints/raceGAN_test4/web...
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# learning rate 0.0000010 -> 0.0000010
# (epoch: 1, iters: 100, time: 0.214, data: 0.146) G_GAN: 0.822 G_L1: 54.424 D_real: 0.684 D_fake: 0.754
# (epoch: 1, iters: 200, time: 0.208, data: 0.001) G_GAN: 0.886 G_L1: 39.618 D_real: 0.660 D_fake: 0.700
# (epoch: 1, iters: 300, time: 0.208, data: 0.002) G_GAN: 0.911 G_L1: 41.031 D_real: 0.559 D_fake: 0.654
# (epoch: 1, iters: 400, time: 0.364, data: 0.002) G_GAN: 1.015 G_L1: 35.672 D_real: 0.512 D_fake: 0.585
# (epoch: 1, iters: 500, time: 0.209, data: 0.001) G_GAN: 1.040 G_L1: 40.432 D_real: 0.489 D_fake: 0.553
# (epoch: 1, iters: 600, time: 0.216, data: 0.001) G_GAN: 1.193 G_L1: 33.183 D_real: 0.349 D_fake: 0.455
# (epoch: 1, iters: 700, time: 0.217, data: 0.002) G_GAN: 1.235 G_L1: 25.361 D_real: 0.476 D_fake: 0.430
# (epoch: 1, iters: 800, time: 0.281, data: 0.003) G_GAN: 1.325 G_L1: 48.952 D_real: 0.329 D_fake: 0.385
# (epoch: 1, iters: 900, time: 0.215, data: 0.001) G_GAN: 1.338 G_L1: 42.269 D_real: 0.359 D_fake: 0.370
# (epoch: 1, iters: 1000, time: 0.215, data: 0.002) G_GAN: 1.456 G_L1: 35.074 D_real: 0.231 D_fake: 0.326
# (epoch: 1, iters: 1100, time: 0.218, data: 0.002) G_GAN: 1.502 G_L1: 51.335 D_real: 0.187 D_fake: 0.301
# (epoch: 1, iters: 1200, time: 0.283, data: 0.002) G_GAN: 1.534 G_L1: 31.757 D_real: 0.377 D_fake: 0.303
# (epoch: 1, iters: 1300, time: 0.214, data: 0.002) G_GAN: 1.652 G_L1: 24.908 D_real: 0.351 D_fake: 0.255
# (epoch: 1, iters: 1400, time: 0.215, data: 0.001) G_GAN: 1.611 G_L1: 33.133 D_real: 0.300 D_fake: 0.284
# (epoch: 1, iters: 1500, time: 0.217, data: 0.002) G_GAN: 1.623 G_L1: 30.358 D_real: 0.156 D_fake: 0.260
# (epoch: 1, iters: 1600, time: 0.278, data: 0.003) G_GAN: 1.822 G_L1: 30.834 D_real: 0.178 D_fake: 0.215
# End of epoch 1 / 200 	 Time Taken: 197 sec
# learning rate 0.0000010 -> 0.0000010
# (epoch: 2, iters: 77, time: 0.218, data: 0.002) G_GAN: 1.845 G_L1: 56.420 D_real: 0.214 D_fake: 0.211
# (epoch: 2, iters: 177, time: 0.219, data: 0.001) G_GAN: 1.870 G_L1: 26.645 D_real: 0.262 D_fake: 0.224
# (epoch: 2, iters: 277, time: 0.220, data: 0.002) G_GAN: 1.992 G_L1: 24.442 D_real: 0.150 D_fake: 0.176
# (epoch: 2, iters: 377, time: 0.347, data: 0.002) G_GAN: 1.867 G_L1: 25.046 D_real: 0.137 D_fake: 0.198
# (epoch: 2, iters: 477, time: 0.222, data: 0.002) G_GAN: 1.965 G_L1: 31.286 D_real: 0.148 D_fake: 0.183
# (epoch: 2, iters: 577, time: 0.221, data: 0.003) G_GAN: 1.528 G_L1: 37.913 D_real: 0.118 D_fake: 0.292
# (epoch: 2, iters: 677, time: 0.216, data: 0.002) G_GAN: 2.063 G_L1: 24.079 D_real: 0.216 D_fake: 0.175
# (epoch: 2, iters: 777, time: 0.281, data: 0.002) G_GAN: 2.107 G_L1: 21.863 D_real: 0.169 D_fake: 0.162
# (epoch: 2, iters: 877, time: 0.222, data: 0.001) G_GAN: 2.098 G_L1: 30.408 D_real: 0.182 D_fake: 0.161
# (epoch: 2, iters: 977, time: 0.215, data: 0.004) G_GAN: 2.210 G_L1: 21.287 D_real: 0.400 D_fake: 0.137
