# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ## Training Model

# %% [markdown]
# #### Very useful to mark succesful training
#
# https://machinelearningmastery.com/practical-guide-to-gan-failure-modes/

# %%
os.getcwd()
# Out:
# '/users/riya/race/gancode'

# %%
os.chdir('/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/')
os.getcwd()
# Out:
# '/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix'

# %%
# !python train.py --dataroot /users/riya/race/gandataset --continue_train --epoch_count 50 --lambda_L1 25.0 --lr .0000002 --display_port 8100 --name raceGAN_combo3 --model pix2pix --gpu_ids 1 --load_size 256 --crop_size 256
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: /users/riya/race/gandataset   	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8100                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 50                            	[default: 1]
#                  gan_mode: vanilla
#                   gpu_ids: 1                             	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
# ...
