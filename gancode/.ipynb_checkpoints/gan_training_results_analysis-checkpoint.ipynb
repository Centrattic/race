# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ## Training Model

# %% [markdown]
# #### Very useful to mark succesful training
#
# https://machinelearningmastery.com/practical-guide-to-gan-failure-modes/

# %%
header_list = ['epoch', 'G_GAN', 'G_L1', 'D_real', 'D_fake']
loss_path = "/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/checkpoints/"

def plot_results(name, skip):
    df = pd.read_csv(loss_path + name + '/loss_clean.csv', skiprows = skip, names = header_list)
    average_results = df.groupby('epoch', as_index=False)[['G_GAN','G_L1','D_real','D_fake']].mean()
    df.plot(x='epoch', y=['G_GAN','D_real','D_fake'], figsize = (15,10), title = 'Loss vs. Epochs', ylabel = 'loss')
    df.plot(x='epoch', y=['G_L1'], figsize = (15,10), title = 'Loss vs. Epochs', ylabel = 'loss', color ='red')

# %%
df_l12 = plot_results('raceGAN_l1_test2', 0)

# %%
plot_results('raceGAN_test2', 0)

# %%
df3.head(16)
# Out:
#    epoch  G_GAN    G_L1  D_real  D_fake
# 0      1  0.998  53.174   0.743   0.601
# 1      1  1.016  46.646   0.550   0.585
# 2      1  1.124  34.647   0.419   0.497
# 3      1  1.246  42.387   0.387   0.432
# 4      1  1.410  43.709   0.286   0.354
# 5      1  1.465  42.273   0.420   0.335
# 6      1  1.650  41.941   0.232   0.265
# 7      1  1.699  33.773   0.270   0.258
# 8      1  1.816  37.147   0.386   0.224
# 9      1  1.927  25.753   0.147   0.189
# 10     1  1.955  51.596   0.290   0.185
# 11     1  2.015  25.744   0.233   0.179
# 12     1  2.067  28.511   0.135   0.168
# 13     1  1.931  48.411   0.161   0.196
# 14     1  2.113  21.648   0.257   0.152
# 15     1  2.124  25.948   0.148   0.156

# %%
plot_results('raceGAN_test4', 0)

# %%
plot_results('raceGAN_test5', 1)
# Out:
#      epoch  G_GAN    G_L1  D_real  D_fake
# 0        1  0.672  52.258   0.630   0.988
# 1        1  0.689  52.488   0.623   0.967
# 2        1  0.699  49.119   0.624   0.915
# 3        1  0.739  47.777   0.597   0.904
# 4        1  0.739  45.632   0.620   0.865
# ...    ...    ...     ...     ...     ...
# 1514    87  2.158  10.150   0.533   0.144
# 1515    87  2.439  26.110   0.017   0.111
# 1516    87  2.188  10.635   0.392   0.137
# 1517    87  2.296  50.892   0.002   0.123
# 1518    87  1.952  35.775   0.011   0.183
#
# [1519 rows x 5 columns]

# %%
plot_results('raceGAN_test6', 0)
