# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ## Training Model

# %% [markdown]
# #### Very useful to mark succesful training
#
# https://machinelearningmastery.com/practical-guide-to-gan-failure-modes/

# %%
os.getcwd()
# Out:
# '/users/riya/race/gancode'

# %%
os.chdir('/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/')
os.getcwd()
# Out:
# '/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix'

# %%
os.listdir('/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/checkpoints/edges2shoes/web/images')
# Out:
# ['epoch070_real_B.png',
#  'epoch003_real_B.png',
#  'epoch058_fake_B.png',
#  'epoch080_real_B.png',
#  'epoch138_real_A.png',
#  'epoch066_real_B.png',
#  'epoch015_real_B.png',
#  'epoch096_real_B.png',
#  'epoch181_real_A.png',
#  'epoch084_fake_B.png',
#  'epoch102_real_A.png',
#  'epoch007_fake_B.png',
#  'epoch074_fake_B.png',
#  'epoch171_real_A.png',
#  'epoch197_real_A.png',
#  'epoch092_fake_B.png',
#  'epoch114_real_A.png',
#  'epoch011_fake_B.png',
#  'epoch062_fake_B.png',
#  'epoch167_real_A.png',
#  'epoch039_real_B.png',
#  'epoch071_real_A.png',
#  'epoch174_fake_B.png',
#  'epoch107_fake_B.png',
#  'epoch002_real_A.png',
#  'epoch184_fake_B.png',
#  'epoch081_real_A.png',
#  'epoch139_real_B.png',
#  'epoch067_real_A.png',
#  'epoch162_fake_B.png',
#  'epoch111_fake_B.png',
#  'epoch014_real_A.png',
#  'epoch192_fake_B.png',
#  'epoch097_real_A.png',
#  'epoch180_real_B.png',
#  'epoch158_fake_B.png',
#  'epoch103_real_B.png',
#  'epoch170_real_B.png',
# ...

# %%
# !python train.py --dataroot /users/riya/race/gandataset --lr 0.000005 --continue_train --epoch 50 --display_port 8100 --name raceGAN_test3 --model pix2pix --gpu_ids 2 --load_size 256 --crop_size 256
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: /users/riya/race/gandataset   	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8100                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: 50                            	[default: latest]
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 2                             	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
os.listdir('/users/riya/race/gancode/pytorch-CycleGAN-and-pix2pix/checkpoints/raceGAN_test3')
